# %%
# 449 slices -> 16 chunks in each chunk, slices are represented as groups, in each -> (3, N) 
# (0, N) -> flat 
# (1, N) -> ID
# (2, N) -> ?
# (449, 999, 999)
# ex. nchuncks = 500/100 = 5, is that true?
import os
import sys
import string
import math
import mahotas
import numpy as np
import h5py
import glob
import sys
sys.path.append('/Users/haneen')
import cv2

# %%
# number of chunks = # original slices/ #compressed slices
def mkdir_safe( dir_to_make ):
    if not os.path.exists( dir_to_make ):
        execute_string = 'mkdir ' + '"' + dir_to_make + '"'
        print execute_string
        print os.system( execute_string )


def load_id_image ( file_path ):
    ids = np.int32( np.array( mahotas.imread( file_path ) ) )
    # ids.shape = (999, 999, 4)
    # ids[0][0] = [  0   0   0 255]
    if len( ids.shape ) == 3:
        ids = ids[ :, :, 2 ] + ids[ :, :, 1 ] * 2**8 + ids[ :, :, 0 ] * 2**16
    else:
        # Read from pipeline format
        ids = ids.transpose() - 1
    return ids


# todo: make this general!
original_input_ids_path       = '../data/skeleton_astrocyte_m3/Astrocytes/'
output_path                   = '../data/skeleton_astrocyte_m3/png_to_h5'
mkdir_safe( output_path )
input_file_format             = 'png'

# count how many input images are loaded
input_search_string  = original_input_ids_path + '/*.' + input_file_format # -> ../input/segmentation/*.png
files                = sorted( glob.glob( input_search_string ) )
print "Found {0} input images in {1}".format( len(files), input_search_string )
nimages_to_process            = len(files) 

if len(files) > 0:
    id_max               = 0;
    id_counts            = np.zeros( 0, dtype=np.int64 );
    tile_index_z         = 0
    K                    = 10 # how many slices per chunk
    
    fout = open(output_path + "/chunkMap.txt", "w")
    
    i, j = 0, 0
    s = 0
    MAX = 0
    D = 3 # dimension
    voxelsPerChunk = 0
    for file in files:  
        print file     
        original_input_ids_name = file
        original_ids = load_id_image( original_input_ids_name )
        ( original_image_num_pixels_x, original_image_num_pixels_y ) = original_ids.shape
        print "original_ids.shape: " + str(original_ids.shape) #(999, 999)
        print np.unique(original_ids)
        N = 0
        filtered_ids, filtered_index = [], []
        for row in original_ids:
            for pixel in row:
                if (pixel):    
                    filtered_ids.append(pixel)
                    filtered_index.append(N)
                
                N = N + 1                    
        print np.unique(filtered_ids)

        # open the hdf5 file every offset, open a file, and write to it the chunk of slices
        if (tile_index_z%K == 0):
            if (voxelsPerChunk > MAX):
                MAX = voxelsPerChunk
            voxelsPerChunk = 0
            if (tile_index_z + K > nimages_to_process):
                i = j
                j = nimages_to_process
                print str(i) + " " + str(j)
                fout.write(str(i) + " " + str(j) + "\n")
                print "tile_index_z: " + str(tile_index_z)
                current_tile_ids_name    = output_path    + '/%d' % ( s ) + '.h5'
                group = 0
                s = s + 1
                print current_tile_ids_name
                hdf5             = h5py.File( current_tile_ids_name, 'w' )
            else:
                print "tile_index_z: " + str(tile_index_z)
                current_tile_ids_name    = output_path    + '/%d' % ( s ) + '.h5'
                group = 0
                s = s + 1
                print current_tile_ids_name
                hdf5             = h5py.File( current_tile_ids_name, 'w' )

                ########## chunkMapping.txt ###############
                # (i, j), i=j, j = i+K, init: i = 0, j = 0 
                i = j
                j = i + K
                print str(i) + " " + str(j)
                fout.write(str(i) + " " + str(j) + "\n")
        
        N = original_image_num_pixels_x * original_image_num_pixels_x

        tile_index_z = tile_index_z + 1
        D = 3
        if (len(filtered_ids) <= 0):
            print "SKIPED!"
            D = 1
            filtered_index.append(0)
            
        
        voxelsPerChunk += len(filtered_ids)
            
        group_name = '%d' % (group) 
        group = group + 1
        dataset = hdf5.get("/").create_dataset(group_name, (D , len(filtered_index)))
        print "Dataset shape: " + str(dataset.shape) + ", Dataset type: " + str(dataset.dtype)

        print "Writing: " + str(tile_index_z)
        if (D == 1):
            dataset[0,:]  = 0
            continue
        
        # flattened ij -> index = x + y * WIDTH
        # original_ids[d] -> d = 1 (y) , d = 0 (x)
        dataset[0, :]  = filtered_index
        # object id
        # filtered_ids, filtered_index
        dataset[1, :] = filtered_ids
        # birth?
        dataset[2, :] = 1

         
        if (tile_index_z%(K) == 0):
            hdf5.close()
            
        if tile_index_z > nimages_to_process:
            print str(tile_index_z) + " >= " + str(nimages_to_process)
            break
                
    fout.close() 
hdf5.close()
# Out:
# mkdir "../data/skeleton_astrocyte_m3/png_to_h5"
# 0
# Found 449 input images in ../data/skeleton_astrocyte_m3/Astrocytes//*.png
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_000.png
# original_ids.shape: (999, 999)
# [0]
# []
# tile_index_z: 0
# ../data/skeleton_astrocyte_m3/png_to_h5/0.h5
# 0 10
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 1
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_001.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 2099), Dataset type: float32
# Writing: 2
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_002.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 55419), Dataset type: float32
# Writing: 3
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_003.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 70182), Dataset type: float32
# Writing: 4
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_004.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 74257), Dataset type: float32
# Writing: 5
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_005.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 77327), Dataset type: float32
# Writing: 6
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_006.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 80116), Dataset type: float32
# Writing: 7
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_007.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 81945), Dataset type: float32
# Writing: 8
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_008.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 83308), Dataset type: float32
# Writing: 9
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_009.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84019), Dataset type: float32
# Writing: 10
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_010.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 10
# ../data/skeleton_astrocyte_m3/png_to_h5/1.h5
# 10 20
# Dataset shape: (3, 84536), Dataset type: float32
# Writing: 11
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_011.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 83759), Dataset type: float32
# Writing: 12
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_012.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 83367), Dataset type: float32
# Writing: 13
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_013.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 82949), Dataset type: float32
# Writing: 14
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_014.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 82925), Dataset type: float32
# Writing: 15
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_015.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 82487), Dataset type: float32
# Writing: 16
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_016.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 81913), Dataset type: float32
# Writing: 17
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_017.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 80510), Dataset type: float32
# Writing: 18
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_018.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 79054), Dataset type: float32
# Writing: 19
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_019.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 78839), Dataset type: float32
# Writing: 20
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_020.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 20
# ../data/skeleton_astrocyte_m3/png_to_h5/2.h5
# 20 30
# Dataset shape: (3, 78267), Dataset type: float32
# Writing: 21
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_021.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 76073), Dataset type: float32
# Writing: 22
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_022.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 72838), Dataset type: float32
# Writing: 23
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_023.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 69928), Dataset type: float32
# Writing: 24
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_024.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 67092), Dataset type: float32
# Writing: 25
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_025.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 65689), Dataset type: float32
# Writing: 26
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_026.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 64328), Dataset type: float32
# Writing: 27
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_027.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 64296), Dataset type: float32
# Writing: 28
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_028.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 63377), Dataset type: float32
# Writing: 29
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_029.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 62722), Dataset type: float32
# Writing: 30
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_030.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 30
# ../data/skeleton_astrocyte_m3/png_to_h5/3.h5
# 30 40
# Dataset shape: (3, 61314), Dataset type: float32
# Writing: 31
# ../data/skeleton_astrocyte_m3/Astrocytes/m3
png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 96935), Dataset type: float32
# Writing: 408
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_408.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 98073), Dataset type: float32
# Writing: 409
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_409.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 98884), Dataset type: float32
# Writing: 410
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_410.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 410
# ../data/skeleton_astrocyte_m3/png_to_h5/41.h5
# 410 420
# Dataset shape: (3, 98373), Dataset type: float32
# Writing: 411
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_411.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 97279), Dataset type: float32
# Writing: 412
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_412.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 96147), Dataset type: float32
# Writing: 413
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_413.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 95367), Dataset type: float32
# Writing: 414
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_414.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 93670), Dataset type: float32
# Writing: 415
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_415.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 92267), Dataset type: float32
# Writing: 416
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_416.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 90911), Dataset type: float32
# Writing: 417
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_417.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 90315), Dataset type: float32
# Writing: 418
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_418.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 89891), Dataset type: float32
# Writing: 419
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_419.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 89720), Dataset type: float32
# Writing: 420
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_420.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 420
# ../data/skeleton_astrocyte_m3/png_to_h5/42.h5
# 420 430
# Dataset shape: (3, 89212), Dataset type: float32
# Writing: 421
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_421.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 88589), Dataset type: float32
# Writing: 422
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_422.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 87147), Dataset type: float32
# Writing: 423
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_423.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 86149), Dataset type: float32
# Writing: 424
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_424.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84748), Dataset type: float32
# Writing: 425
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_425.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84067), Dataset type: float32
# Writing: 426
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_426.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84060), Dataset type: float32
# Writing: 427
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_427.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84516), Dataset type: float32
# Writing: 428
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_428.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 85147), Dataset type: float32
# Writing: 429
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_429.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84871), Dataset type: float32
# Writing: 430
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_430.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# tile_index_z: 430
# ../data/skeleton_astrocyte_m3/png_to_h5/43.h5
# 430 440
# Dataset shape: (3, 84696), Dataset type: float32
# Writing: 431
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_431.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84586), Dataset type: float32
# Writing: 432
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_432.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84680), Dataset type: float32
# Writing: 433
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_433.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84248), Dataset type: float32
# Writing: 434
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_434.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84438), Dataset type: float32
# Writing: 435
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_435.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 84869), Dataset type: float32
# Writing: 436
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_436.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 86542), Dataset type: float32
# Writing: 437
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_437.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 87894), Dataset type: float32
# Writing: 438
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_438.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 90274), Dataset type: float32
# Writing: 439
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_439.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 91372), Dataset type: float32
# Writing: 440
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_440.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# 440 449
# tile_index_z: 440
# ../data/skeleton_astrocyte_m3/png_to_h5/44.h5
# Dataset shape: (3, 92515), Dataset type: float32
# Writing: 441
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_441.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 89161), Dataset type: float32
# Writing: 442
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_442.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 56755), Dataset type: float32
# Writing: 443
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_443.png
# original_ids.shape: (999, 999)
# [  0 745]
# [745]
# Dataset shape: (3, 818), Dataset type: float32
# Writing: 444
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_444.png
# original_ids.shape: (999, 999)
# [0]
# []
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 445
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_445.png
# original_ids.shape: (999, 999)
# [0]
# []
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 446
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_446.png
# original_ids.shape: (999, 999)
# [0]
# []
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 447
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_447.png
# original_ids.shape: (999, 999)
# [0]
# []
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 448
# ../data/skeleton_astrocyte_m3/Astrocytes/m3_448.png
# original_ids.shape: (999, 999)
# [0]
# []
# SKIPED!
# Dataset shape: (1, 1), Dataset type: float32
# Writing: 449

# %%
"done"
# Out:
# 'done'
